# %%
import pandas as pd
import requests

# %%
response = requests.get(' Paste the URL ')

# %%
df=pd.DataFrame(response.json()['results'])

# %%
df = pd.DataFrame() 
df# Empty dataframe creation
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,n):
    response=requests.get(' URL '.format(i))
    temp_df=pd.DataFrame(response.json()['result'])[['col1', 'col2']]
    df=df.append(temp_df,ignore_index=True)

# %%
df.to_csv('hello.csv')  # converting json to csv
