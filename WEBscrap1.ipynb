# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://bollyflix.do/web-series/netflix/page/1/', headers=headers).text

# %%
soup=BeautifulSoup(webpage, 'html.parser')

# %%
soup.find_all('h1')[0].text   # All the shits present in h1 heading
# Out:
# 'Category: NETFLIX'

# %%
len(soup.find_all('h1')[0].text)
# Out:
# 17

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# Download Single’s Inferno (Season 01-05) Multi Audio {Hindi-English-Korean} NetFlix WEB Series 480p | 720p | 1080p WEB-DL ESub [S05E04]
# Download WWE: Unreal (Season 1-2) Dual Audio [Hindi-English] WEB Series 720p | 1080p WEB-DL MSubs
# Download Taskaree: The Smuggler’s Web (Season 1) Multi Audio [Hindi-Tamil-Telugu] WEB Series 480p | 720p | 1080p WEB-DL MSubs
# Download Can This Love Be Translated? (Season 1) Multi Audio {Hindi-Korean-English} WEB Series 480p | 720p | 1080p WEB-DL ESub
# Download The Rookie (Season 1 – 8) English WEB Series 720p | 1080p WEB-DL ESub [S08E01 Added]
# Download Love Is Blind: Germany (Season 1) Dual Audio [English-German] WEB Series 720p | 1080p WEB-DL MSubs
# Download His & Hers (Season 1) Dual Audio [Hindi-English] WEB Series 480p | 720p | 1080p WEB-DL MSubs
# Download Emily in Paris (Season 01-05) Dual Audio {Hindi-English} NetFlix WEB Series 720p | 1080p WEB-DL ESubs
# ...

# %%
for i in soup.find_all('a'):
    print(i.text.strip())
# Out:
# Menu
# 🏠 HOME
# 🎬 MOVIES
# SOUTH HINDI DUBBED
# ADULT MOVIES
# BOLLYWOOD
# DUAL AUDIO
# HINDI DUBBED
# HOLLYWOOD
# MULTI AUDIO
# PUNJABI
# BENGALI
# 🔗 GENRE
# ACTION
# ADVENTURE
# ANIMATION
# COMEDY
# CRIME
# DRAMA
# FANTASY
# HISTORICAL
# HORROR
# MYSTERY
# POLITICAL
# ROMANCE
# SCI-FI
# THRILLER
# 📅 YEAR
# 2026
# 2025
# 2024
# 2023
# 2022
# 2021
# 2016-2020
# 2016
# 2017
# 2018
# 2019
# 2020
# 2011-2015
# 2006-2010
# 2001-2005
# 1880-2000
# ☠️ QUALITY
# 480p MOVIES
# 720p MOVIES
# 1080p MOVIES
# 300MB MOVIES
# 500MB MOVIES
# 700MB MOVIES
# 900MB MOVIES
# 1GB MOVIES
# 📺 TV SHOWS
# 🌐 WEB SERIES
# NETFLIX
# AMAZON PRIME VIDEO
# KOREAN DRAMA
# HINDI DUBBED SERIES
# HOTSTAR
# HULU
# MX PLAYER ORIGINALS
# VOOT SELECT
# ONGOING SERIES
# ANIME
#
# Download Single’s Inferno (Season 01-05) Multi Audio {Hindi-English-Korean} NetFlix WEB Series 480p | 720p | 1080p WEB-DL ESub [S05E04]
#
# Download WWE: Unreal (Season 1-2) Dual Audio [Hindi-English] WEB Series 720p | 1080p WEB-DL MSubs
#
# ...

# %%
len(soup.find_all('h2', class_='title front-view-title'))
# Out:
# 20

# %%
company=soup.find_all('h2', class_="title front-view-title")
len(company)
# Out:
# 20

# %%
print(i.prettify())
# Out:
# <h2 class="title front-view-title">
#  <a data-wpel-link="internal" href="https://bollyflix.do/singles-inferno-multi-audio-hindi-english-korean-netflix-web-series/">
#   Download Single’s Inferno (Season 01-05) Multi Audio {Hindi-English-Korean} NetFlix WEB Series 480p | 720p | 1080p WEB-DL ESub [S05E04]
#  </a>
# </h2>

# %%
title1=[]
title2=[]
title3=[]

for i in company:
    h2 = i.find('h2', class_='title front-view-title')
    if h2:
        title1.append(h2.text.strip())
d={'title1':title1}
df=pd.DataFrame(d)
df
# Out:
# Empty DataFrame
# Columns: [title1]
# Index: []

# %%
final=pd.DataFrame()
for j in range(1, 20):
    url='https://bollyflix.do/web-series/netflix/page/{}/'.format(j)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage=requests.get('https://bollyflix.do/web-series/netflix/page/1/', headers=headers).text
    soup=BeautifulSoup(webpage, 'html.parser')
    company=soup.find_all('h2', class_="title front-view-title")
    title1=[]

    for i in company:
        h2 = i.find('h2', class_='title front-view-title')
    if h2:
        title1.append(h2.text.strip())
    h2 = i.find('h2', class_='title front-view-title')
    df=pd.DataFrame(d)
